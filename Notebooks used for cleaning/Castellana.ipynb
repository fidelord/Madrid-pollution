# %%
import pandas as pd 
df1=pd.read_csv('csvs_per_year/madrid_2001.csv')
df1
# Out:
#                        date    BEN    CO   EBE    MXY  NMHC       NO_2  \
# 0       2001-08-01 01:00:00    NaN  0.37   NaN    NaN   NaN  58.400002
# 1       2001-08-01 01:00:00   1.50  0.34  1.49   4.10  0.07  56.250000
# 2       2001-08-01 01:00:00    NaN  0.28   NaN    NaN   NaN  50.660000
# 3       2001-08-01 01:00:00    NaN  0.47   NaN    NaN   NaN  69.790001
# 4       2001-08-01 01:00:00    NaN  0.39   NaN    NaN   NaN  22.830000
# ...                     ...    ...   ...   ...    ...   ...        ...
# 217867  2001-04-01 00:00:00  10.45  1.81   NaN    NaN   NaN  73.000000
# 217868  2001-04-01 00:00:00   5.20  0.69  4.56    NaN  0.13  71.080002
# 217869  2001-04-01 00:00:00   0.49  1.09   NaN   1.00  0.19  76.279999
# 217870  2001-04-01 00:00:00   5.62  1.01  5.04  11.38   NaN  80.019997
# 217871  2001-04-01 00:00:00   8.09  1.62  6.66  13.04  0.18  76.809998
#
#                NOx   OXY        O_3        PM10   PXY       SO_2   TCH    TOL  \
# ...

# %%
import pandas as pd 
df2=pd.read_csv('csvs_per_year/madrid_2002.csv')
df2
# Out:
#                        date   BEN    CO   EBE    MXY  NMHC        NO_2  \
# 0       2002-04-01 01:00:00   NaN  1.39   NaN    NaN   NaN  145.100006
# 1       2002-04-01 01:00:00  1.93  0.71  2.33   6.20  0.15   98.150002
# 2       2002-04-01 01:00:00   NaN  0.80   NaN    NaN   NaN  103.699997
# 3       2002-04-01 01:00:00   NaN  1.61   NaN    NaN   NaN   97.599998
# 4       2002-04-01 01:00:00   NaN  1.90   NaN    NaN   NaN   92.089996
# ...                     ...   ...   ...   ...    ...   ...         ...
# 217291  2002-11-01 00:00:00  4.16  1.14   NaN    NaN   NaN   81.080002
# 217292  2002-11-01 00:00:00  3.67  1.73  2.89    NaN  0.38  113.900002
# 217293  2002-11-01 00:00:00  1.37  0.58  1.17   2.37  0.15   65.389999
# 217294  2002-11-01 00:00:00  4.51  0.91  4.83  10.99   NaN  149.800003
# 217295  2002-11-01 00:00:00  3.11  1.17  3.00   7.77  0.26   80.110001
#
#                NOx   OXY    O_3       PM10   PXY       SO_2   TCH        TOL  \
# ...

# %%
import pandas as pd 
df3=pd.read_csv('csvs_per_year/madrid_2003.csv')
df3
# Out:
#                        date   BEN    CO   EBE   MXY  NMHC       NO_2  \
# 0       2003-03-01 01:00:00   NaN  1.72   NaN   NaN   NaN  73.900002
# 1       2003-03-01 01:00:00   NaN  1.45   NaN   NaN  0.26  72.110001
# 2       2003-03-01 01:00:00   NaN  1.57   NaN   NaN   NaN  80.559998
# 3       2003-03-01 01:00:00   NaN  2.45   NaN   NaN   NaN  78.370003
# 4       2003-03-01 01:00:00   NaN  3.26   NaN   NaN   NaN  96.250000
# ...                     ...   ...   ...   ...   ...   ...        ...
# 243979  2003-10-01 00:00:00  0.20  0.16  2.01  3.17  0.02  31.799999
# 243980  2003-10-01 00:00:00  0.32  0.08  0.36  0.72   NaN  10.450000
# 243981  2003-10-01 00:00:00   NaN   NaN   NaN   NaN  0.07  34.639999
# 243982  2003-10-01 00:00:00   NaN   NaN   NaN   NaN  0.07  32.580002
# 243983  2003-10-01 00:00:00  1.00  0.29  2.15  6.41  0.07  37.150002
#
#                NOx   OXY        O_3       PM10   PXY       SO_2   TCH   TOL  \
# ...

# %%
import pandas as pd 
df4=pd.read_csv('csvs_per_year/madrid_2004.csv')
df4
# Out:
#                        date   BEN    CO   EBE   MXY  NMHC        NO_2  \
# 0       2004-08-01 01:00:00   NaN  0.66   NaN   NaN   NaN   89.550003
# 1       2004-08-01 01:00:00  2.66  0.54  2.99  6.08  0.18   51.799999
# 2       2004-08-01 01:00:00   NaN  1.02   NaN   NaN   NaN   93.389999
# 3       2004-08-01 01:00:00   NaN  0.53   NaN   NaN   NaN   87.290001
# 4       2004-08-01 01:00:00   NaN  0.17   NaN   NaN   NaN   34.910000
# ...                     ...   ...   ...   ...   ...   ...         ...
# 245491  2004-06-01 00:00:00  0.75  0.21  0.85  1.55  0.07   59.580002
# 245492  2004-06-01 00:00:00  2.49  0.75  2.44  4.57   NaN   97.139999
# 245493  2004-06-01 00:00:00   NaN   NaN   NaN   NaN  0.13  102.699997
# 245494  2004-06-01 00:00:00   NaN   NaN   NaN   NaN  0.09   82.599998
# 245495  2004-06-01 00:00:00  3.01  0.67  2.78  5.12  0.20   92.550003
#
#                NOx   OXY        O_3       PM10       PM25   PXY   SO_2   TCH  \
# ...

# %%
import pandas as pd 
df5=pd.read_csv('csvs_per_year/madrid_2005.csv')
df5
# Out:
#                        date   BEN    CO   EBE   MXY  NMHC       NO_2  \
# 0       2005-11-01 01:00:00   NaN  0.77   NaN   NaN   NaN  57.130001
# 1       2005-11-01 01:00:00  1.52  0.65  1.49  4.57  0.25  86.559998
# 2       2005-11-01 01:00:00   NaN  0.40   NaN   NaN   NaN  46.119999
# 3       2005-11-01 01:00:00   NaN  0.42   NaN   NaN   NaN  37.220001
# 4       2005-11-01 01:00:00   NaN  0.57   NaN   NaN   NaN  32.160000
# ...                     ...   ...   ...   ...   ...   ...        ...
# 236995  2006-01-01 00:00:00  1.08  0.36  1.01   NaN  0.11  21.990000
# 236996  2006-01-01 00:00:00  0.39  0.54  1.00  1.00  0.11   2.200000
# 236997  2006-01-01 00:00:00  0.19   NaN  0.26   NaN  0.08  26.730000
# 236998  2006-01-01 00:00:00  0.14   NaN  1.00   NaN  0.06  13.770000
# 236999  2006-01-01 00:00:00  0.50  0.40  0.73  1.84  0.13  20.940001
#
#                NOx   OXY        O_3   PM10   PM25   PXY   SO_2   TCH   TOL  \
# ...

# %%
import pandas as pd 
df6=pd.read_csv('csvs_per_year/madrid_2006.csv')
df6
# Out:
#                        date   BEN    CO   EBE   MXY  NMHC        NO_2  \
# 0       2006-02-01 01:00:00   NaN  1.84   NaN   NaN   NaN  155.100006
# 1       2006-02-01 01:00:00  1.68  1.01  2.38  6.36  0.32   94.339996
# 2       2006-02-01 01:00:00   NaN  1.25   NaN   NaN   NaN   66.800003
# 3       2006-02-01 01:00:00   NaN  1.68   NaN   NaN   NaN  103.000000
# 4       2006-02-01 01:00:00   NaN  1.31   NaN   NaN   NaN  105.400002
# ...                     ...   ...   ...   ...   ...   ...         ...
# 230563  2006-05-01 00:00:00  5.88  0.83  6.23   NaN  0.20  112.500000
# 230564  2006-05-01 00:00:00  0.76  0.32  0.48  1.09  0.08   51.900002
# 230565  2006-05-01 00:00:00  0.96   NaN  0.69   NaN  0.19  135.100006
# 230566  2006-05-01 00:00:00  0.50   NaN  0.67   NaN  0.10   82.599998
# 230567  2006-05-01 00:00:00  1.95  0.74  1.99  4.00  0.24  107.300003
#
#                NOx   OXY        O_3       PM10       PM25   PXY       SO_2  \
# ...

# %%
import pandas as pd 
df7=pd.read_csv('csvs_per_year/madrid_2007.csv')
df7
# Out:
#                        date   BEN    CO   EBE   MXY  NMHC        NO_2  \
# 0       2007-12-01 01:00:00   NaN  2.86   NaN   NaN   NaN  282.200012
# 1       2007-12-01 01:00:00   NaN  1.82   NaN   NaN   NaN   86.419998
# 2       2007-12-01 01:00:00   NaN  1.47   NaN   NaN   NaN   94.639999
# 3       2007-12-01 01:00:00   NaN  1.64   NaN   NaN   NaN  127.900002
# 4       2007-12-01 01:00:00  4.64  1.86  4.26  7.98  0.57  145.100006
# ...                     ...   ...   ...   ...   ...   ...         ...
# 225115  2007-03-01 00:00:00  0.30  0.45  1.00  0.30  0.26    8.690000
# 225116  2007-03-01 00:00:00   NaN  0.16   NaN   NaN   NaN   46.820000
# 225117  2007-03-01 00:00:00  0.24   NaN  0.20   NaN  0.09   51.259998
# 225118  2007-03-01 00:00:00  0.11   NaN  1.00   NaN  0.05   24.240000
# 225119  2007-03-01 00:00:00  0.53  0.40  1.00  1.70  0.12   32.360001
#
#                 NOx   OXY        O_3        PM10   PM25   PXY       SO_2  \
# ...

# %%
import pandas as pd 
df8=pd.read_csv('csvs_per_year/madrid_2008.csv')
df8
# Out:
#                        date   BEN    CO   EBE   MXY  NMHC        NO_2  \
# 0       2008-06-01 01:00:00   NaN  0.47   NaN   NaN   NaN   83.089996
# 1       2008-06-01 01:00:00   NaN  0.59   NaN   NaN   NaN   94.820000
# 2       2008-06-01 01:00:00   NaN  0.55   NaN   NaN   NaN   75.919998
# 3       2008-06-01 01:00:00   NaN  0.36   NaN   NaN   NaN   61.029999
# 4       2008-06-01 01:00:00  1.68  0.80  1.70  3.01  0.30  105.199997
# ...                     ...   ...   ...   ...   ...   ...         ...
# 226387  2008-11-01 00:00:00  0.48  0.30  0.57  1.00  0.31   13.050000
# 226388  2008-11-01 00:00:00   NaN  0.30   NaN   NaN   NaN   41.880001
# 226389  2008-11-01 00:00:00  0.25   NaN  0.56   NaN  0.11   83.610001
# 226390  2008-11-01 00:00:00  0.54   NaN  2.70   NaN  0.18   70.639999
# 226391  2008-11-01 00:00:00  0.75  0.36  1.20  2.75  0.16   58.240002
#
#                NOx   OXY        O_3       PM10   PM25   PXY   SO_2   TCH  \
# ...

# %%
import pandas as pd 
df9=pd.read_csv('csvs_per_year/madrid_2009.csv')
df9
# Out:
#                        date   BEN    CO   EBE   MXY  NMHC       NO_2  \
# 0       2009-10-01 01:00:00   NaN  0.27   NaN   NaN   NaN  39.889999
# 1       2009-10-01 01:00:00   NaN  0.22   NaN   NaN   NaN  21.230000
# 2       2009-10-01 01:00:00   NaN  0.18   NaN   NaN   NaN  31.230000
# 3       2009-10-01 01:00:00  0.95  0.33  1.43  2.68  0.25  55.180000
# 4       2009-10-01 01:00:00   NaN  0.41   NaN   NaN  0.12  61.349998
# ...                     ...   ...   ...   ...   ...   ...        ...
# 215683  2009-06-01 00:00:00  0.50  0.22  0.39  0.75  0.09  22.000000
# 215684  2009-06-01 00:00:00   NaN  0.31   NaN   NaN   NaN  76.110001
# 215685  2009-06-01 00:00:00  0.13   NaN  0.86   NaN  0.23  81.050003
# 215686  2009-06-01 00:00:00  0.21   NaN  2.96   NaN  0.10  72.419998
# 215687  2009-06-01 00:00:00  0.37  0.32  0.99  1.36  0.14  54.290001
#
#                NOx   OXY        O_3       PM10   PM25   PXY  SO_2   TCH   TOL  \
# ...

# %%
import pandas as pd 
df10=pd.read_csv('csvs_per_year/madrid_2010.csv')
df10
# Out:
#                        date   BEN    CO   EBE  MXY  NMHC        NO_2  \
# 0       2010-03-01 01:00:00   NaN  0.29   NaN  NaN   NaN   25.090000
# 1       2010-03-01 01:00:00   NaN  0.27   NaN  NaN   NaN   24.879999
# 2       2010-03-01 01:00:00   NaN  0.28   NaN  NaN   NaN   17.410000
# 3       2010-03-01 01:00:00  0.38  0.24  1.74  NaN  0.05   15.610000
# 4       2010-03-01 01:00:00  0.79   NaN  1.32  NaN   NaN   21.430000
# ...                     ...   ...   ...   ...  ...   ...         ...
# 209443  2010-08-01 00:00:00   NaN  0.55   NaN  NaN   NaN  125.000000
# 209444  2010-08-01 00:00:00   NaN  0.27   NaN  NaN   NaN   45.709999
# 209445  2010-08-01 00:00:00   NaN   NaN   NaN  NaN  0.24   46.560001
# 209446  2010-08-01 00:00:00   NaN   NaN   NaN  NaN   NaN   46.770000
# 209447  2010-08-01 00:00:00  0.92  0.43  0.71  NaN  0.25   76.330002
#
#                NOx  OXY        O_3       PM10       PM25  PXY   SO_2   TCH  \
# ...

# %%
import pandas as pd 
df11=pd.read_csv('csvs_per_year/madrid_2011.csv')
df11
# Out:
#                        date  BEN   CO  EBE  NMHC     NO  NO_2   O_3  PM10  \
# 0       2011-11-01 01:00:00  NaN  1.0  NaN   NaN  154.0  84.0   NaN   NaN
# 1       2011-11-01 01:00:00  2.5  0.4  3.5  0.26   68.0  92.0   3.0  40.0
# 2       2011-11-01 01:00:00  2.9  NaN  3.8   NaN   96.0  99.0   NaN   NaN
# 3       2011-11-01 01:00:00  NaN  0.6  NaN   NaN   60.0  83.0   2.0   NaN
# 4       2011-11-01 01:00:00  NaN  NaN  NaN   NaN   44.0  62.0   3.0   NaN
# ...                     ...  ...  ...  ...   ...    ...   ...   ...   ...
# 209923  2011-09-01 00:00:00  NaN  0.2  NaN   NaN    5.0  19.0  44.0   NaN
# 209924  2011-09-01 00:00:00  NaN  0.1  NaN   NaN    6.0  29.0   NaN  11.0
# 209925  2011-09-01 00:00:00  NaN  NaN  NaN  0.23    1.0  21.0  28.0   NaN
# 209926  2011-09-01 00:00:00  NaN  NaN  NaN   NaN    3.0  15.0  48.0   NaN
# 209927  2011-09-01 00:00:00  NaN  NaN  NaN   NaN    4.0  33.0  38.0  13.0
#
#         PM25  SO_2   TCH  TOL   station
# ...

# %%
import pandas as pd 
df12=pd.read_csv('csvs_per_year/madrid_2012.csv')
df12
# Out:
#                        date  BEN   CO  EBE  NMHC    NO  NO_2   O_3  PM10  \
# 0       2012-09-01 01:00:00  NaN  0.2  NaN   NaN   7.0  18.0   NaN   NaN
# 1       2012-09-01 01:00:00  0.3  0.3  0.7   NaN   3.0  18.0  55.0  10.0
# 2       2012-09-01 01:00:00  0.4  NaN  0.7   NaN   2.0  10.0   NaN   NaN
# 3       2012-09-01 01:00:00  NaN  0.2  NaN   NaN   1.0   6.0  50.0   NaN
# 4       2012-09-01 01:00:00  NaN  NaN  NaN   NaN   1.0  13.0  54.0   NaN
# ...                     ...  ...  ...  ...   ...   ...   ...   ...   ...
# 210715  2012-03-01 00:00:00  NaN  0.6  NaN   NaN  37.0  84.0  14.0   NaN
# 210716  2012-03-01 00:00:00  NaN  0.4  NaN   NaN   5.0  76.0   NaN  17.0
# 210717  2012-03-01 00:00:00  NaN  NaN  NaN  0.34   3.0  41.0  24.0   NaN
# 210718  2012-03-01 00:00:00  NaN  NaN  NaN   NaN   2.0  44.0  36.0   NaN
# 210719  2012-03-01 00:00:00  NaN  NaN  NaN   NaN   2.0  56.0  40.0  18.0
#
#         PM25  SO_2   TCH  TOL   station
# 0        NaN   2.0   NaN  NaN  28079004
# ...

# %%
import pandas as pd 
df13=pd.read_csv('csvs_per_year/madrid_2013.csv')
df13
# Out:
#                        date  BEN   CO  EBE  NMHC     NO   NO_2   O_3  PM10  \
# 0       2013-11-01 01:00:00  NaN  0.6  NaN   NaN  135.0   74.0   NaN   NaN
# 1       2013-11-01 01:00:00  1.5  0.5  1.3   NaN   71.0   83.0   2.0  23.0
# 2       2013-11-01 01:00:00  3.9  NaN  2.8   NaN   49.0   70.0   NaN   NaN
# 3       2013-11-01 01:00:00  NaN  0.5  NaN   NaN   82.0   87.0   3.0   NaN
# 4       2013-11-01 01:00:00  NaN  NaN  NaN   NaN  242.0  111.0   2.0   NaN
# ...                     ...  ...  ...  ...   ...    ...    ...   ...   ...
# 209875  2013-03-01 00:00:00  NaN  0.4  NaN   NaN    8.0   39.0  52.0   NaN
# 209876  2013-03-01 00:00:00  NaN  0.4  NaN   NaN    1.0   11.0   NaN   6.0
# 209877  2013-03-01 00:00:00  NaN  NaN  NaN   NaN    2.0    4.0  75.0   NaN
# 209878  2013-03-01 00:00:00  NaN  NaN  NaN   NaN    2.0   11.0  52.0   NaN
# 209879  2013-03-01 00:00:00  NaN  NaN  NaN   NaN    1.0   10.0  75.0   3.0
#
#         PM25  SO_2  TCH  TOL   station
# ...

# %%
 
df14=pd.read_csv('csvs_per_year/madrid_2014.csv')
df14
# Out:
#                        date  BEN   CO  EBE  NMHC    NO  NO_2   O_3  PM10  \
# 0       2014-06-01 01:00:00  NaN  0.2  NaN   NaN   3.0  10.0   NaN   NaN
# 1       2014-06-01 01:00:00  0.2  0.2  0.1  0.11   3.0  17.0  68.0  10.0
# 2       2014-06-01 01:00:00  0.3  NaN  0.1   NaN   2.0   6.0   NaN   NaN
# 3       2014-06-01 01:00:00  NaN  0.2  NaN   NaN   1.0   6.0  79.0   NaN
# 4       2014-06-01 01:00:00  NaN  NaN  NaN   NaN   1.0   6.0  75.0   NaN
# ...                     ...  ...  ...  ...   ...   ...   ...   ...   ...
# 210019  2014-09-01 00:00:00  NaN  0.5  NaN   NaN  20.0  84.0  29.0   NaN
# 210020  2014-09-01 00:00:00  NaN  0.3  NaN   NaN   1.0  22.0   NaN  15.0
# 210021  2014-09-01 00:00:00  NaN  NaN  NaN   NaN   1.0  13.0  70.0   NaN
# 210022  2014-09-01 00:00:00  NaN  NaN  NaN   NaN   3.0  38.0  42.0   NaN
# 210023  2014-09-01 00:00:00  NaN  NaN  NaN   NaN   1.0  26.0  65.0  11.0
#
#         PM25  SO_2   TCH  TOL   station
# 0        NaN   3.0   NaN  NaN  28079004
# ...

# %%
import pandas as pd 
df15=pd.read_csv('csvs_per_year/madrid_2015.csv')
df15
# Out:
#                        date  BEN   CO  EBE  NMHC    NO   NO_2   O_3  PM10  \
# 0       2015-10-01 01:00:00  NaN  0.8  NaN   NaN  90.0   82.0   NaN   NaN
# 1       2015-10-01 01:00:00  2.0  0.8  1.6  0.33  40.0   95.0   4.0  37.0
# 2       2015-10-01 01:00:00  3.1  NaN  1.8   NaN  29.0   97.0   NaN   NaN
# 3       2015-10-01 01:00:00  NaN  0.6  NaN   NaN  30.0  103.0   2.0   NaN
# 4       2015-10-01 01:00:00  NaN  NaN  NaN   NaN  95.0   96.0   2.0   NaN
# ...                     ...  ...  ...  ...   ...   ...    ...   ...   ...
# 210091  2015-08-01 00:00:00  NaN  0.2  NaN   NaN  11.0   33.0  53.0   NaN
# 210092  2015-08-01 00:00:00  NaN  0.2  NaN   NaN   1.0    5.0   NaN  26.0
# 210093  2015-08-01 00:00:00  NaN  NaN  NaN   NaN   1.0    7.0  74.0   NaN
# 210094  2015-08-01 00:00:00  NaN  NaN  NaN   NaN   3.0    7.0  65.0   NaN
# 210095  2015-08-01 00:00:00  NaN  NaN  NaN   NaN   1.0    9.0  54.0  29.0
#
#         PM25  SO_2   TCH  TOL   station
# ...

# %%
import pandas as pd 
df16=pd.read_csv('csvs_per_year/madrid_2016.csv')
df16
# Out:
#                        date  BEN   CO  EBE  NMHC     NO   NO_2   O_3  PM10  \
# 0       2016-11-01 01:00:00  NaN  0.7  NaN   NaN  153.0   77.0   NaN   NaN
# 1       2016-11-01 01:00:00  3.1  1.1  2.0  0.53  260.0  144.0   4.0  46.0
# 2       2016-11-01 01:00:00  5.9  NaN  7.5   NaN  297.0  139.0   NaN   NaN
# 3       2016-11-01 01:00:00  NaN  1.0  NaN   NaN  154.0  113.0   2.0   NaN
# 4       2016-11-01 01:00:00  NaN  NaN  NaN   NaN  275.0  127.0   2.0   NaN
# ...                     ...  ...  ...  ...   ...    ...    ...   ...   ...
# 209491  2016-07-01 00:00:00  NaN  0.2  NaN   NaN    2.0   29.0  73.0   NaN
# 209492  2016-07-01 00:00:00  NaN  0.3  NaN   NaN    1.0   29.0   NaN  36.0
# 209493  2016-07-01 00:00:00  NaN  NaN  NaN   NaN    1.0   19.0  71.0   NaN
# 209494  2016-07-01 00:00:00  NaN  NaN  NaN   NaN    6.0   17.0  85.0   NaN
# 209495  2016-07-01 00:00:00  NaN  NaN  NaN   NaN    2.0   46.0  61.0  34.0
#
#         PM25  SO_2   TCH   TOL   station
# ...

# %%
import pandas as pd 
df17=pd.read_csv('csvs_per_year/madrid_2017.csv')
df17
# Out:
#                        date  BEN  CH4   CO  EBE  NMHC   NO  NO_2  NOx   O_3  \
# 0       2017-06-01 01:00:00  NaN  NaN  0.3  NaN   NaN  4.0  38.0  NaN   NaN
# 1       2017-06-01 01:00:00  0.6  NaN  0.3  0.4  0.08  3.0  39.0  NaN  71.0
# 2       2017-06-01 01:00:00  0.2  NaN  NaN  0.1   NaN  1.0  14.0  NaN   NaN
# 3       2017-06-01 01:00:00  NaN  NaN  0.2  NaN   NaN  1.0   9.0  NaN  91.0
# 4       2017-06-01 01:00:00  NaN  NaN  NaN  NaN   NaN  1.0  19.0  NaN  69.0
# ...                     ...  ...  ...  ...  ...   ...  ...   ...  ...   ...
# 210115  2017-08-01 00:00:00  NaN  NaN  0.2  NaN   NaN  1.0  27.0  NaN  65.0
# 210116  2017-08-01 00:00:00  NaN  NaN  0.2  NaN   NaN  1.0  14.0  NaN   NaN
# 210117  2017-08-01 00:00:00  NaN  NaN  NaN  NaN   NaN  1.0   4.0  NaN  83.0
# 210118  2017-08-01 00:00:00  NaN  NaN  NaN  NaN   NaN  1.0  11.0  NaN  78.0
# 210119  2017-08-01 00:00:00  NaN  NaN  NaN  NaN   NaN  1.0  14.0  NaN  77.0
#
#         PM10  PM25  SO_2  TCH  TOL   station
# ...

# %%
import pandas as pd 
df18=pd.read_csv('csvs_per_year/madrid_2018.csv')
df18
# Out:
#                       date  BEN   CH4   CO  EBE  NMHC     NO   NO_2    NOx  \
# 0      2018-03-01 01:00:00  NaN   NaN  0.3  NaN   NaN    1.0   29.0   31.0
# 1      2018-03-01 01:00:00  0.5  1.39  0.3  0.2  0.02    6.0   40.0   49.0
# 2      2018-03-01 01:00:00  0.4   NaN  NaN  0.2   NaN    4.0   41.0   47.0
# 3      2018-03-01 01:00:00  NaN   NaN  0.3  NaN   NaN    1.0   35.0   37.0
# 4      2018-03-01 01:00:00  NaN   NaN  NaN  NaN   NaN    1.0   27.0   29.0
# ...                    ...  ...   ...  ...  ...   ...    ...    ...    ...
# 69091  2018-02-01 00:00:00  NaN   NaN  0.5  NaN   NaN   66.0   91.0  192.0
# 69092  2018-02-01 00:00:00  NaN   NaN  0.7  NaN   NaN   87.0  107.0  241.0
# 69093  2018-02-01 00:00:00  NaN   NaN  NaN  NaN   NaN   28.0   48.0   91.0
# 69094  2018-02-01 00:00:00  NaN   NaN  NaN  NaN   NaN  141.0  103.0  320.0
# 69095  2018-02-01 00:00:00  NaN   NaN  NaN  NaN   NaN   69.0   96.0  202.0
#
#         O_3  PM10  PM25  SO_2   TCH  TOL   station
# ...

# %%
#Concatenating from year 2001 to 2018
new_df=pd.concat([df1, df2, df3,df4,df5,df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18], ignore_index=True)
new_df
# Out:
#                         date  BEN    CO   EBE  MXY  NMHC        NO_2  \
# 0        2001-08-01 01:00:00  NaN  0.37   NaN  NaN   NaN   58.400002
# 1        2001-08-01 01:00:00  1.5  0.34  1.49  4.1  0.07   56.250000
# 2        2001-08-01 01:00:00  NaN  0.28   NaN  NaN   NaN   50.660000
# 3        2001-08-01 01:00:00  NaN  0.47   NaN  NaN   NaN   69.790001
# 4        2001-08-01 01:00:00  NaN  0.39   NaN  NaN   NaN   22.830000
# ...                      ...  ...   ...   ...  ...   ...         ...
# 3808219  2018-02-01 00:00:00  NaN  0.50   NaN  NaN   NaN   91.000000
# 3808220  2018-02-01 00:00:00  NaN  0.70   NaN  NaN   NaN  107.000000
# 3808221  2018-02-01 00:00:00  NaN   NaN   NaN  NaN   NaN   48.000000
# 3808222  2018-02-01 00:00:00  NaN   NaN   NaN  NaN   NaN  103.000000
# 3808223  2018-02-01 00:00:00  NaN   NaN   NaN  NaN   NaN   96.000000
#
#                 NOx   OXY        O_3        PM10   PXY   SO_2   TCH    TOL  \
# ...

# %%
#new_df

# %%
#new_df.describe()

# %%
from datetime import datetime
new_df['date']=pd.to_datetime(new_df['date'], infer_datetime_format=True)

# %%
new_df
# Out:
#                        date  BEN    CO   EBE  MXY  NMHC        NO_2  \
# 0       2001-08-01 01:00:00  NaN  0.37   NaN  NaN   NaN   58.400002
# 1       2001-08-01 01:00:00  1.5  0.34  1.49  4.1  0.07   56.250000
# 2       2001-08-01 01:00:00  NaN  0.28   NaN  NaN   NaN   50.660000
# 3       2001-08-01 01:00:00  NaN  0.47   NaN  NaN   NaN   69.790001
# 4       2001-08-01 01:00:00  NaN  0.39   NaN  NaN   NaN   22.830000
# ...                     ...  ...   ...   ...  ...   ...         ...
# 3808219 2018-02-01 00:00:00  NaN  0.50   NaN  NaN   NaN   91.000000
# 3808220 2018-02-01 00:00:00  NaN  0.70   NaN  NaN   NaN  107.000000
# 3808221 2018-02-01 00:00:00  NaN   NaN   NaN  NaN   NaN   48.000000
# 3808222 2018-02-01 00:00:00  NaN   NaN   NaN  NaN   NaN  103.000000
# 3808223 2018-02-01 00:00:00  NaN   NaN   NaN  NaN   NaN   96.000000
#
#                 NOx   OXY        O_3        PM10   PXY   SO_2   TCH    TOL  \
# ...

# %%
#Station name=Castellana
df_stations=new_df.groupby('station')
df_station_15=df_stations.get_group(28079048)
df_station_15
# Out:
#                        date  BEN  CO  EBE  MXY  NMHC        NO_2         NOx  \
# 2093245 2010-08-01 01:00:00  NaN NaN  NaN  NaN   NaN   59.450001   63.340000
# 2093267 2010-08-01 02:00:00  NaN NaN  NaN  NaN   NaN   61.689999   65.410004
# 2093289 2010-08-01 03:00:00  NaN NaN  NaN  NaN   NaN   71.230003   75.230003
# 2093311 2010-08-01 04:00:00  NaN NaN  NaN  NaN   NaN   73.680000   78.099998
# 2093333 2010-08-01 05:00:00  NaN NaN  NaN  NaN   NaN   58.250000   61.349998
# ...                     ...  ...  ..  ...  ...   ...         ...         ...
# 3808118 2018-01-31 20:00:00  NaN NaN  NaN  NaN   NaN  122.000000  299.000000
# 3808142 2018-01-31 21:00:00  NaN NaN  NaN  NaN   NaN  132.000000  398.000000
# 3808166 2018-01-31 22:00:00  NaN NaN  NaN  NaN   NaN  120.000000  325.000000
# 3808190 2018-01-31 23:00:00  NaN NaN  NaN  NaN   NaN  134.000000  441.000000
# 3808214 2018-02-01 00:00:00  NaN NaN  NaN  NaN   NaN  102.000000  217.000000
#
# ...

# %%
df_station_15.isnull().sum()
# Out:
# date       0
# NO_2       0
# NOx        0
# PM10       0
# station    0
# PM25       0
# NO         0
# dtype: int64

# %%
df_station_15.drop(['BEN','CO','EBE','MXY','NMHC','OXY', 'O_3', 'PXY','SO_2','TCH','TOL', 'CH4'],axis=1,inplace= True)
# Out:
# C:\Users\OvaBeatz\AppData\Local\Temp\ipykernel_2156\137888105.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_station_15.drop(['BEN','CO','EBE','MXY','NMHC','OXY', 'O_3', 'PXY','SO_2','TCH','TOL', 'CH4'],axis=1,inplace= True)

# %%
df_station_15['NO_2'].fillna(0,inplace = True)
# Out:
# C:\Users\OvaBeatz\AppData\Local\Temp\ipykernel_2156\3930346798.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_station_15['NO_2'].fillna(0,inplace = True)

# %%
df_station_15['NOx'].fillna(df_station_15['NOx'].median(), inplace =True)
# Out:
# C:\Users\OvaBeatz\AppData\Local\Temp\ipykernel_2156\788037482.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_station_15['NOx'].fillna(df_station_15['NOx'].median(), inplace =True)

# %%
df_station_15['PM25'].fillna(df_station_15['PM25'].median(), inplace =True)
# Out:
# C:\Users\OvaBeatz\AppData\Local\Temp\ipykernel_2156\399327845.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_station_15['PM25'].fillna(df_station_15['PM25'].median(), inplace =True)

# %%
df_station_15['PM10'].fillna(df_station_15['PM10'].median(), inplace =True)
# Out:
# C:\Users\OvaBeatz\AppData\Local\Temp\ipykernel_2156\3455007458.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_station_15['PM10'].fillna(df_station_15['PM10'].median(), inplace =True)

# %%
df_station_15['NO'].fillna(df_station_15['NO'].median(), inplace =True)
# Out:
# C:\Users\OvaBeatz\AppData\Local\Temp\ipykernel_2156\2868650930.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_station_15['NO'].fillna(df_station_15['NO'].median(), inplace =True)

# %%
df_station_15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 69288 entries, 2093245 to 3808214
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     69288 non-null  datetime64[ns]
#  1   NO_2     69288 non-null  float64
#  2   NOx      69288 non-null  float64
#  3   PM10     69288 non-null  float64
#  4   station  69288 non-null  int64
#  5   PM25     69288 non-null  float64
#  6   NO       69288 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 4.2 MB

# %%
df_station_15.to_csv('Castellana.csv', index=False)
